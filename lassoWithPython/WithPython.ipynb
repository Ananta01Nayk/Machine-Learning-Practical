# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.datasets import load_diabetes
import numpy as np
import pandas as pd

# %%
x,y = load_diabetes(return_X_y=True)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=43)

# %%
class LassoReg:
    def __init__(self,alpha):
        
        self.intercept_= None
        self.cofie_ = None
        self.Neumator = None
        self.Denometor = None
        self.alpha = alpha
    
    def fit(self,x_train,y_train):
        self.x_train = np.insert(x_train,0,1,axis=1)
        self.y_train = y_train
        I = np.eye(len(x_train[0]))
        self.Neumator = self.x_train - self.x_train.mean()
        self.Denometor = self.y_train.mean() - self.y_train.mean()
        
        m = (self.Neumator-self.alpha*I)/self.Denometor
        self.intercept_ = m[0]
        self.cofie_ = m[1:]
    def predict(self,x_test):
        self.x_train = x_test
        return self.cofie_*self.text + self.intercept_

# %%
lr=LassoReg(0.1)

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 lr.fit(x_train,y_train)
#
# Cell In[17], line 17, in LassoReg.fit(self, x_train, y_train)
#      13         I = np.eye(len(x_train[0]))
#      14         self.Neumator = self.x_train - self.x_train.mean()
#      15         self.Denometor = self.y_train.mean() - self.y_train.mean()
#      16
# ---> 17         m = (self.Neumator-self.alpha*I)/self.Denometor
#      18         self.intercept_ = m[0]
#      19         self.cofie_ = m[1:]
#
# ValueError: operands could not be broadcast together with shapes (353,11) (10,10)
